# %% [markdown]
# # Final Dissertation Software — GPU Training
# This notebook runs the **same final codebase** on Google Colab. It is not a separate software version.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Set this path to the project folder you copied into Google Drive.

# %%
PROJECT = '/content/drive/MyDrive/depression_detection_final'
# %cd $PROJECT

# %%
# !python -m pip install --upgrade pip
# !pip install -r requirements.txt

# %%
import torch
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))

# %% [markdown]
# The dataset ZIP should be at `data/raw/reddit_depression_dataset-compressed.zip`.

# %%
# !python prepare_data.py

# %%
# !python train_baseline.py

# %%
# !python train_model.py --batch-size 16

# %%
import json
from pathlib import Path
for p in [Path('artifacts/results/baseline_metrics.json'), Path('artifacts/results/hybrid_metrics.json')]:
    if p.exists():
        m=json.loads(p.read_text())
        print('\n', p.name)
        for k in ['accuracy','precision','recall','f1','roc_auc']:
            print(f'{k}: {m[k]:.4f}')

# %% [markdown]
# After training, the final model is in `artifacts/model/` and the dissertation evidence is in `artifacts/results/`. Because the project folder is on Drive, these files persist automatically.
